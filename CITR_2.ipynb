# %%
import zipfile
import pandas as pd
from sklearn.preprocessing import LabelEncoder, MinMaxScaler

with zipfile.ZipFile("adult.zip", "r") as zip_ref:
    zip_ref.extractall()

columns = [
    "Age", "Workclass", "Fnlwgt", "Education", "Education_Num",
    "Marital_Status", "Occupation", "Relationship", "Race",
    "Sex", "Capital_Gain", "Capital_Loss", "Hours_Per_Week",
    "Native_Country", "Income"
]

df = pd.read_csv(
    "adult.data",
    header=None,
    names=columns,
    skipinitialspace=True,
    na_values="?"
)

print("Original Shape:", df.shape)

print("\nMissing Values:")
print(df.isnull().sum())

for col in df.columns:
    if df[col].dtype == "object":
        df[col].fillna(df[col].mode()[0], inplace=True)
    else:
        df[col].fillna(df[col].median(), inplace=True)

df.drop_duplicates(inplace=True)

print("\nCleaning Completed")
print("Shape after Cleaning:", df.shape)

extra = df[["Age", "Income"]]
df = pd.concat([df, extra.add_suffix("_Copy")], axis=1)

print("\nIntegration Completed")
print("Shape after Integration:", df.shape)

le = LabelEncoder()

numeric_cols = ["Fnlwgt", "Education_Num",
                "Capital_Gain", "Capital_Loss", "Hours_Per_Week"]

df[numeric_cols] = scaler.fit_transform(df[numeric_cols])

# Keep Age as integer
df["Age"] = df["Age"].astype(int)

print("\nTransformation Completed")

df.drop(["Age_Copy", "Income_Copy"], axis=1, inplace=True)

print("\nReduction Completed")
print("Final Shape:", df.shape)


print("\nFinal Dataset (First 10 Rows):")
print(df.head(10))

df.to_csv("adult_processed.csv", index=False)

print("\nProcessed dataset saved as 'adult_processed.csv'")
# Out:
# Original Shape: (32561, 15)
#
# Missing Values:
# Age                  0
# Workclass         1836
# Fnlwgt               0
# Education            0
# Education_Num        0
# Marital_Status       0
# Occupation        1843
# Relationship         0
# Race                 0
# Sex                  0
# Capital_Gain         0
# Capital_Loss         0
# Hours_Per_Week       0
# Native_Country     583
# Income               0
# dtype: int64
#
# Cleaning Completed
# Shape after Cleaning: (32537, 15)
#
# Integration Completed
# Shape after Integration: (32537, 17)
#
# Transformation Completed
#
# Reduction Completed
# Final Shape: (32537, 15)
#
# Final Dataset (First 10 Rows):
#    Age         Workclass    Fnlwgt  Education  Education_Num  \
# 0   39         State-gov  0.044302  Bachelors       0.800000
# 1   50  Self-emp-not-inc  0.048238  Bachelors       0.800000
# 2   38           Private  0.138113    HS-grad       0.533333
# 3   53           Private  0.151068       11th       0.400000
# ...
